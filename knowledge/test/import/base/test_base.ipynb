# %%
#测试path使用
from pathlib import Path
file="/path/to/document.md"
path=Path(file)
print(path)
print(path.name)
print(path.suffix)
print(path.stem)
# Out:
# \path\to\document.md
# document.md
# .md
# document

# %%
path.stem
# Out:
# 'adasdsadas'
